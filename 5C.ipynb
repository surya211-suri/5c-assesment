# %%
import pandas as pd
from datetime import datetime

# %%
df = pd.read_csv("/content/sales_data_1.csv")

# %%
df
# Out:
#          Date Firm bought from  Buying price   Customer  Selling price  \
# 0  2023-08-21          Vendor6         72.11  Customer7          91.58
# 1  2023-08-21          Vendor4         75.08  Customer7          83.71
# 2  2023-08-21          Vendor7         83.93  Customer2         103.76
# 3  2023-08-21          Vendor7         52.01  Customer3          64.53
# 4  2023-08-21          Vendor2         98.91  Customer5         140.92
# ..        ...              ...           ...        ...            ...
# 65 2023-08-27          Vendor4         64.82  Customer6          87.45
# 66 2023-08-27          Vendor8         88.79  Customer3         105.59
# 67 2023-08-27          Vendor5         63.30  Customer5          92.92
# 68 2023-08-27          Vendor5         94.06  Customer5         125.67
# 69 2023-08-27          Vendor5         56.28  Customer6          82.16
#
#     Quantity sold DayOfWeek
# 0              44    Monday
# 1              17    Monday
# ...

# %%
# Convert the "Date" column to a datetime object and extract the day of the week
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%y')
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
df['Profit'] = (df['Selling price'] - df['Buying price']) * df['Quantity sold']

# %%
# 1. Calculate the overall gross margin for the business
total_revenue = (df['Selling price'] * df['Quantity sold']).sum()
total_cost = (df['Buying price'] * df['Quantity sold']).sum()
gross_margin = (total_revenue - total_cost) / total_revenue

# 2. Find the most profitable vendor
vendor_profit = df.groupby('Vendor')['Profit'].sum()
most_profitable_vendor = vendor_profit.idxmax()

# 3. Find the least profitable customer
customer_profit = df.groupby('Customer')['Profit'].sum()
least_profitable_customer = customer_profit.idxmin()

# 4. Find the most profitable day of the week
day_profit = df.groupby('DayOfWeek')['Profit'].sum()
most_profitable_day = day_profit.idxmax()

# 5. Find the least profitable day of the week
least_profitable_day = day_profit.idxmin()

print(f"1. Overall Gross Margin: {gross_margin * 100:.2f}%")
print(f"2. Most Profitable Vendor: {most_profitable_vendor}")
print(f"3. Least Profitable Customer: {least_profitable_customer}")
print(f"4. Most Profitable Day of the Week: {most_profitable_day}")
print(f"5. Least Profitable Day of the Week: {least_profitable_day}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-2b1afdd683eb> in <cell line: 7>()
#       5
#       6 # 2. Find the most profitable vendor
# ----> 7 vendor_profit = df.groupby('Vendor')['Profit'].sum()
#       8 most_profitable_vendor = vendor_profit.idxmax()
#       9
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    8400         axis = self._get_axis_number(axis)
#    8401
# -> 8402         return DataFrameGroupBy(
#    8403             obj=self,
#    8404             keys=by,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...
